# %%
import cv2
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# Load the image
image = cv2.imread('red_line_image.jpg')

# %%
# Convert image to HSV color space
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# %%
# Define lower and upper thresholds for red color in HSV
lower_red1 = np.array([0, 50, 50])
upper_red1 = np.array([10, 255, 255])
lower_red2 = np.array([170, 50, 50])
upper_red2 = np.array([180, 255, 255])

# Create masks for red pixels using the thresholds
red_mask1 = cv2.inRange(hsv_image, lower_red1, upper_red1)
red_mask2 = cv2.inRange(hsv_image, lower_red2, upper_red2)
red_mask = cv2.bitwise_or(red_mask1, red_mask2)

# Apply Canny edge detection on the red mask
edges = cv2.Canny(red_mask, 50, 150, apertureSize=3)

# Find contours in the edge image
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
# Check if contours were found
if contours:
    # Extract the largest contour (assuming it corresponds to the red line)
    largest_contour = max(contours, key=cv2.contourArea)

    # Extract the coordinates of the red line
    x_coords = largest_contour[:, 0, 0]
    y_coords = largest_contour[:, 0, 1]

    # Print the coordinates of the red dots
    for x, y in zip(x_coords, y_coords):
        print(f"Red dot coordinates: ({x}, {y})")

    # Fit a polynomial curve to the coordinates
    degree = 3  # Degree of the polynomial curve
    coeffs = np.polyfit(x_coords, y_coords, degree)
    poly_func = np.poly1d(coeffs)

    # Generate x values for plotting the curve
    x_plot = np.linspace(min(x_coords), max(x_coords), 100)

    # Evaluate the polynomial function for the plotted x values
    y_plot = poly_func(x_plot)

    # Plot the original image with the detected red line and the fitted curve
    plt.figure(figsize=(8, 6))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.plot(x_coords, y_coords, 'ro', label='Detected Red Line')
    plt.plot(x_plot, y_plot, 'b-', label='Fitted Curve')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Fitting a Curve to the Detected Red Line')
    plt.legend()
    plt.show()
else:
    print("No red line detected.")
# Out:
# Red dot coordinates: (1032, 39)
# Red dot coordinates: (1032, 44)
# Red dot coordinates: (1030, 46)
# Red dot coordinates: (1029, 46)
# Red dot coordinates: (1028, 47)
# Red dot coordinates: (1025, 47)
# Red dot coordinates: (1024, 48)
# Red dot coordinates: (1023, 48)
# Red dot coordinates: (1022, 49)
# Red dot coordinates: (1021, 49)
# Red dot coordinates: (1020, 50)
# Red dot coordinates: (1019, 50)
# Red dot coordinates: (1017, 52)
# Red dot coordinates: (1016, 52)
# Red dot coordinates: (1014, 54)
# Red dot coordinates: (1013, 54)
# Red dot coordinates: (1010, 57)
# Red dot coordinates: (1009, 57)
# Red dot coordinates: (1008, 58)
# Red dot coordinates: (1007, 58)
# Red dot coordinates: (1005, 60)
# Red dot coordinates: (1004, 60)
# Red dot coordinates: (1003, 61)
# Red dot coordinates: (1002, 61)
# Red dot coordinates: (1000, 63)
# Red dot coordinates: (997, 63)
# Red dot coordinates: (996, 64)
# Red dot coordinates: (994, 64)
# Red dot coordinates: (993, 65)
# Red dot coordinates: (991, 65)
# Red dot coordinates: (990, 66)
# Red dot coordinates: (989, 66)
# Red dot coordinates: (988, 67)
# Red dot coordinates: (987, 67)
# Red dot coordinates: (986, 68)
# Red dot coordinates: (985, 68)
# Red dot coordinates: (984, 69)
# Red dot coordinates: (982, 69)
# Red dot coordinates: (981, 70)
# Red dot coordinates: (980, 70)
# Red dot coordinates: (979, 71)
# Red dot coordinates: (978, 71)
# Red dot coordinates: (977, 72)
# Red dot coordinates: (976, 72)
# Red dot coordinates: (975, 73)
# Red dot coordinates: (974, 73)
# Red dot coordinates: (973, 74)
# Red dot coordinates: (972, 74)
# Red dot coordinates: (970, 76)
# Red dot coordinates: (969, 76)
# Red dot coordinates: (968, 77)
# Red dot coordinates: (967, 77)
# Red dot coordinates: (965, 79)
# Red dot coordinates: (964, 79)
# Red dot coordinates: (961, 82)
# Red dot coordinates: (960, 82)
# Red dot coordinates: (956, 86)
# Red dot coordinates: (955, 86)
# Red dot coordinates: (951, 90)
# Red dot coordinates: (948, 90)
# Red dot coordinates: (947, 91)
# Red dot coordinates: (941, 91)
# Red dot coordinates: (939, 93)
# Red dot coordinates: (940, 94)
# Red dot coordinates: (940, 95)
# Red dot coordinates: (942, 97)
# Red dot coordinates: (942, 98)
# Red dot coordinates: (943, 99)
# Red dot coordinates: (943, 104)
# Red dot coordinates: (944, 105)
# Red dot coordinates: (944, 112)
# Red dot coordinates: (945, 113)
# Red dot coordinates: (945, 115)
# Red dot coordinates: (946, 116)
# Red dot coordinates: (946, 119)
# Red dot coordinates: (947, 120)
# Red dot coordinates: (947, 131)
# Red dot coordinates: (948, 132)
# Red dot coordinates: (948, 137)
# Red dot coordinates: (949, 138)
# Red dot coordinates: (949, 141)
# Red dot coordinates: (950, 142)
# Red dot coordinates: (950, 144)
# Red dot coordinates: (951, 145)
# Red dot coordinates: (951, 154)
# Red dot coordinates: (952, 155)
# Red dot coordinates: (952, 158)
# Red dot coordinates: (953, 159)
# Red dot coordinates: (953, 165)
# Red dot coordinates: (952, 166)
# Red dot coordinates: (952, 170)
# Red dot coordinates: (947, 175)
# Red dot coordinates: (947, 176)
# Red dot coordinates: (944, 179)
# Red dot coordinates: (944, 180)
# Red dot coordinates: (939, 185)
# Red dot coordinates: (938, 185)
# Red dot coordinates: (936, 187)
# Red dot coordinates: (935, 187)
# Red dot coordinates: (929, 193)
# Red dot coordinates: (928, 193)
# Red dot coordinates: (925, 196)
# Red dot coordinates: (923, 196)
# Red dot coordinates: (922, 195)
# Red dot coordinates: (921, 195)
# Red dot coordinates: (920, 196)
# Red dot coordinates: (899, 196)
# Red dot coordinates: (898, 197)
# Red dot coordinates: (895, 197)
# Red dot coordinates: (894, 198)
# Red dot coordinates: (893, 198)
# Red dot coordinates: (891, 200)
# Red dot coordinates: (891, 201)
# Red dot coordinates: (892, 202)
# Red dot coordinates: (892, 212)
# Red dot coordinates: (893, 213)
# Red dot coordinates: (893, 214)
# Red dot coordinates: (894, 215)
# Red dot coordinates: (894, 219)
# Red dot coordinates: (893, 220)
# Red dot coordinates: (893, 221)
# Red dot coordinates: (892, 222)
# Red dot coordinates: (890, 222)
# Red dot coordinates: (888, 224)
# Red dot coordinates: (888, 225)
# Red dot coordinates: (887, 226)
# Red dot coordinates: (887, 227)
# Red dot coordinates: (886, 228)
# Red dot coordinates: (880, 228)
# Red dot coordinates: (879, 227)
# Red dot coordinates: (874, 227)
# Red dot coordinates: (873, 226)
# Red dot coordinates: (869, 226)
# Red dot coordinates: (868, 225)
# Red dot coordinates: (867, 225)
# Red dot coordinates: (866, 224)
# Red dot coordinates: (833, 224)
# Red dot coordinates: (831, 222)
# Red dot coordinates: (831, 219)
# Red dot coordinates: (829, 217)
# Red dot coordinates: (828, 217)
# Red dot coordinates: (827, 216)
# Red dot coordinates: (827, 215)
# Red dot coordinates: (826, 214)
# Red dot coordinates: (826, 198)
# Red dot coordinates: (825, 197)
# Red dot coordinates: (825, 184)
# Red dot coordinates: (824, 183)
# Red dot coordinates: (824, 175)
# Red dot coordinates: (823, 174)
# Red dot coordinates: (823, 148)
# Red dot coordinates: (822, 147)
# Red dot coordinates: (822, 143)
# Red dot coordinates: (821, 143)
# Red dot coordinates: (820, 142)
# Red dot coordinates: (819, 142)
# Red dot coordinates: (816, 139)
# Red dot coordinates: (815, 139)
# Red dot coordinates: (814, 138)
# Red dot coordinates: (809, 138)
# Red dot coordinates: (808, 137)
# Red dot coordinates: (807, 137)
# Red dot coordinates: (805, 135)
# Red dot coordinates: (804, 135)
# Red dot coordinates: (803, 134)
# Red dot coordinates: (802, 134)
# Red dot coordinates: (801, 133)
# Red dot coordinates: (799, 133)
# Red dot coordinates: (798, 132)
# Red dot coordinates: (797, 133)
# Red dot coordinates: (795, 133)
# Red dot coordinates: (794, 134)
# Red dot coordinates: (792, 134)
# Red dot coordinates: (791, 135)
# Red dot coordinates: (789, 135)
# Red dot coordinates: (788, 136)
# Red dot coordinates: (786, 136)
# Red dot coordinates: (785, 137)
# Red dot coordinates: (783, 137)
# Red dot coordinates: (782, 138)
# Red dot coordinates: (780, 138)
# Red dot coordinates: (779, 139)
# Red dot coordinates: (776, 139)
# Red dot coordinates: (775, 140)
# Red dot coordinates: (772, 140)
# Red dot coordinates: (771, 141)
# Red dot coordinates: (768, 141)
# Red dot coordinates: (767, 142)
# Red dot coordinates: (765, 142)
# Red dot coordinates: (764, 143)
# Red dot coordinates: (762, 143)
# Red dot coordinates: (761, 144)
# Red dot coordinates: (758, 144)
# Red dot coordinates: (757, 145)
# Red dot coordinates: (753, 145)
# Red dot coordinates: (752, 146)
# Red dot coordinates: (745, 146)
# Red dot coordinates: (744, 147)
# Red dot coordinates: (735, 147)
# Red dot coordinates: (734, 148)
# Red dot coordinates: (724, 148)
# Red dot coordinates: (723, 149)
# Red dot coordinates: (715, 149)
# Red dot coordinates: (714, 150)
# Red dot coordinates: (704, 150)
# Red dot coordinates: (703, 151)
# Red dot coordinates: (687, 151)
# Red dot coordinates: (686, 152)
# Red dot coordinates: (684, 152)
# Red dot coordinates: (683, 153)
# Red dot coordinates: (681, 153)
# Red dot coordinates: (680, 154)
# Red dot coordinates: (678, 154)
# Red dot coordinates: (677, 155)
# Red dot coordinates: (673, 155)
# Red dot coordinates: (672, 156)
# Red dot coordinates: (671, 156)
# Red dot coordinates: (670, 157)
# Red dot coordinates: (669, 157)
# Red dot coordinates: (668, 158)
# Red dot coordinates: (667, 158)
# Red dot coordinates: (666, 159)
# Red dot coordinates: (665, 159)
# Red dot coordinates: (664, 160)
# Red dot coordinates: (662, 160)
# Red dot coordinates: (661, 161)
# Red dot coordinates: (659, 161)
# Red dot coordinates: (658, 162)
# Red dot coordinates: (657, 162)
# Red dot coordinates: (656, 163)
# Red dot coordinates: (655, 163)
# Red dot coordinates: (654, 164)
# Red dot coordinates: (653, 164)
# Red dot coordinates: (650, 167)
# Red dot coordinates: (649, 167)
# Red dot coordinates: (647, 169)
# Red dot coordinates: (644, 169)
# Red dot coordinates: (643, 170)
# Red dot coordinates: (641, 170)
# Red dot coordinates: (640, 171)
# Red dot coordinates: (639, 171)
# Red dot coordinates: (638, 172)
# Red dot coordinates: (637, 172)
# Red dot coordinates: (636, 173)
# Red dot coordinates: (633, 173)
# Red dot coordinates: (632, 174)
# Red dot coordinates: (631, 174)
# Red dot coordinates: (629, 176)
# Red dot coordinates: (627, 176)
# Red dot coordinates: (626, 177)
# Red dot coordinates: (625, 177)
# Red dot coordinates: (624, 178)
# Red dot coordinates: (612, 178)
# Red dot coordinates: (611, 177)
# Red dot coordinates: (610, 177)
# Red dot coordinates: (609, 176)
# Red dot coordinates: (608, 176)
# Red dot coordinates: (606, 174)
# Red dot coordinates: (606, 170)
# Red dot coordinates: (605, 169)
# Red dot coordinates: (605, 162)
# Red dot coordinates: (604, 161)
# Red dot coordinates: (604, 158)
# Red dot coordinates: (603, 157)
# Red dot coordinates: (603, 143)
# Red dot coordinates: (602, 142)
# Red dot coordinates: (602, 139)
# Red dot coordinates: (601, 138)
# Red dot coordinates: (601, 134)
# Red dot coordinates: (600, 133)
# Red dot coordinates: (600, 129)
# Red dot coordinates: (599, 128)
# Red dot coordinates: (599, 117)
# Red dot coordinates: (598, 116)
# Red dot coordinates: (598, 108)
# Red dot coordinates: (597, 107)
# Red dot coordinates: (597, 101)
# Red dot coordinates: (595, 99)
# Red dot coordinates: (594, 99)
# Red dot coordinates: (593, 98)
# Red dot coordinates: (592, 98)
# Red dot coordinates: (591, 97)
# Red dot coordinates: (589, 97)
# Red dot coordinates: (588, 96)
# Red dot coordinates: (587, 96)
# Red dot coordinates: (586, 95)
# Red dot coordinates: (585, 95)
# Red dot coordinates: (584, 94)
# Red dot coordinates: (582, 94)
# Red dot coordinates: (581, 93)
# Red dot coordinates: (580, 93)
# Red dot coordinates: (579, 92)
# Red dot coordinates: (578, 92)
# Red dot coordinates: (577, 91)
# Red dot coordinates: (576, 91)
# Red dot coordinates: (575, 90)
# Red dot coordinates: (573, 90)
# Red dot coordinates: (572, 89)
# Red dot coordinates: (571, 89)
# Red dot coordinates: (570, 88)
# Red dot coordinates: (569, 88)
# Red dot coordinates: (568, 87)
# Red dot coordinates: (567, 87)
# Red dot coordinates: (566, 86)
# Red dot coordinates: (565, 86)
# Red dot coordinates: (564, 85)
# Red dot coordinates: (563, 85)
# Red dot coordinates: (561, 83)
# Red dot coordinates: (560, 83)
# Red dot coordinates: (559, 82)
# Red dot coordinates: (558, 82)
# Red dot coordinates: (557, 81)
# Red dot coordinates: (556, 81)
# Red dot coordinates: (555, 80)
# Red dot coordinates: (554, 80)
# Red dot coordinates: (553, 79)
# Red dot coordinates: (552, 79)
# Red dot coordinates: (551, 78)
# Red dot coordinates: (548, 78)
# Red dot coordinates: (547, 77)
# Red dot coordinates: (545, 77)
# Red dot coordinates: (544, 76)
# Red dot coordinates: (536, 76)
# Red dot coordinates: (535, 77)
# Red dot coordinates: (529, 77)
# Red dot coordinates: (528, 78)
# Red dot coordinates: (516, 78)
# Red dot coordinates: (515, 79)
# Red dot coordinates: (482, 79)
# Red dot coordinates: (481, 80)
# Red dot coordinates: (469, 80)
# Red dot coordinates: (468, 81)
# Red dot coordinates: (461, 81)
# Red dot coordinates: (460, 82)
# Red dot coordinates: (454, 82)
# Red dot coordinates: (453, 83)
# Red dot coordinates: (450, 83)
# Red dot coordinates: (449, 84)
# Red dot coordinates: (445, 84)
# Red dot coordinates: (444, 85)
# Red dot coordinates: (440, 85)
# Red dot coordinates: (439, 86)
# Red dot coordinates: (433, 86)
# Red dot coordinates: (432, 87)
# Red dot coordinates: (428, 87)
# Red dot coordinates: (427, 88)
# Red dot coordinates: (426, 88)
# Red dot coordinates: (425, 89)
# Red dot coordinates: (423, 89)
# Red dot coordinates: (422, 90)
# Red dot coordinates: (420, 90)
# Red dot coordinates: (419, 91)
# Red dot coordinates: (418, 91)
# Red dot coordinates: (418, 98)
# Red dot coordinates: (419, 99)
# Red dot coordinates: (419, 104)
# Red dot coordinates: (418, 105)
# Red dot coordinates: (418, 119)
# Red dot coordinates: (417, 120)
# Red dot coordinates: (417, 134)
# Red dot coordinates: (418, 135)
# Red dot coordinates: (418, 137)
# Red dot coordinates: (417, 138)
# Red dot coordinates: (417, 139)
# Red dot coordinates: (416, 140)
# Red dot coordinates: (416, 141)
# Red dot coordinates: (407, 150)
# Red dot coordinates: (406, 150)
# Red dot coordinates: (405, 151)
# Red dot coordinates: (405, 152)
# Red dot coordinates: (401, 156)
# Red dot coordinates: (400, 156)
# Red dot coordinates: (400, 157)
# Red dot coordinates: (398, 159)
# Red dot coordinates: (397, 159)
# Red dot coordinates: (396, 160)
# Red dot coordinates: (395, 160)
# Red dot coordinates: (394, 161)
# Red dot coordinates: (391, 161)
# Red dot coordinates: (390, 162)
# Red dot coordinates: (388, 162)
# Red dot coordinates: (387, 163)
# Red dot coordinates: (373, 163)
# Red dot coordinates: (372, 162)
# Red dot coordinates: (371, 162)
# Red dot coordinates: (370, 161)
# Red dot coordinates: (368, 161)
# Red dot coordinates: (367, 160)
# Red dot coordinates: (366, 160)
# Red dot coordinates: (365, 159)
# Red dot coordinates: (360, 159)
# Red dot coordinates: (359, 158)
# Red dot coordinates: (354, 158)
# Red dot coordinates: (353, 157)
# Red dot coordinates: (350, 157)
# Red dot coordinates: (349, 156)
# Red dot coordinates: (333, 156)
# Red dot coordinates: (332, 155)
# Red dot coordinates: (328, 155)
# Red dot coordinates: (327, 154)
# Red dot coordinates: (325, 154)
# Red dot coordinates: (324, 153)
# Red dot coordinates: (319, 153)
# Red dot coordinates: (318, 152)
# Red dot coordinates: (315, 152)
# Red dot coordinates: (314, 151)
# Red dot coordinates: (308, 151)
# Red dot coordinates: (307, 150)
# Red dot coordinates: (296, 150)
# Red dot coordinates: (295, 149)
# Red dot coordinates: (287, 149)
# Red dot coordinates: (286, 148)
# Red dot coordinates: (284, 148)
# Red dot coordinates: (283, 147)
# Red dot coordinates: (281, 147)
# Red dot coordinates: (280, 146)
# Red dot coordinates: (274, 146)
# Red dot coordinates: (273, 145)
# Red dot coordinates: (263, 145)
# Red dot coordinates: (262, 144)
# Red dot coordinates: (255, 144)
# Red dot coordinates: (254, 143)
# Red dot coordinates: (245, 143)
# Red dot coordinates: (244, 142)
# Red dot coordinates: (239, 142)
# Red dot coordinates: (238, 141)
# Red dot coordinates: (228, 141)
# Red dot coordinates: (226, 139)
# Red dot coordinates: (226, 133)
# Red dot coordinates: (225, 132)
# Red dot coordinates: (223, 132)
# Red dot coordinates: (222, 131)
# Red dot coordinates: (222, 130)
# Red dot coordinates: (221, 129)
# Red dot coordinates: (221, 128)
# Red dot coordinates: (220, 127)
# Red dot coordinates: (220, 126)
# Red dot coordinates: (219, 125)
# Red dot coordinates: (219, 123)
# Red dot coordinates: (218, 122)
# Red dot coordinates: (218, 118)
# Red dot coordinates: (217, 117)
# Red dot coordinates: (217, 115)
# Red dot coordinates: (216, 114)
# Red dot coordinates: (216, 111)
# Red dot coordinates: (215, 110)
# Red dot coordinates: (215, 107)
# Red dot coordinates: (214, 106)
# Red dot coordinates: (214, 103)
# Red dot coordinates: (213, 102)
# Red dot coordinates: (213, 98)
# Red dot coordinates: (212, 97)
# Red dot coordinates: (212, 92)
# Red dot coordinates: (211, 91)
# Red dot coordinates: (211, 82)
# Red dot coordinates: (210, 81)
# Red dot coordinates: (210, 77)
# Red dot coordinates: (209, 77)
# Red dot coordinates: (208, 76)
# Red dot coordinates: (205, 76)
# Red dot coordinates: (204, 75)
# Red dot coordinates: (201, 75)
# Red dot coordinates: (200, 74)
# Red dot coordinates: (199, 74)
# Red dot coordinates: (197, 72)
# Red dot coordinates: (196, 72)
# Red dot coordinates: (194, 70)
# Red dot coordinates: (193, 70)
# Red dot coordinates: (190, 67)
# Red dot coordinates: (189, 67)
# Red dot coordinates: (188, 66)
# Red dot coordinates: (187, 66)
# Red dot coordinates: (186, 67)
# Red dot coordinates: (185, 67)
# Red dot coordinates: (183, 69)
# Red dot coordinates: (182, 69)
# Red dot coordinates: (180, 71)
# Red dot coordinates: (179, 71)
# Red dot coordinates: (176, 74)
# Red dot coordinates: (175, 74)
# Red dot coordinates: (173, 76)
# Red dot coordinates: (172, 76)
# Red dot coordinates: (168, 80)
# Red dot coordinates: (167, 80)
# Red dot coordinates: (166, 81)
# Red dot coordinates: (165, 81)
# Red dot coordinates: (164, 82)
# Red dot coordinates: (163, 82)
# Red dot coordinates: (162, 83)
# Red dot coordinates: (161, 83)
# Red dot coordinates: (159, 85)
# Red dot coordinates: (158, 85)
# Red dot coordinates: (156, 87)
# Red dot coordinates: (155, 87)
# Red dot coordinates: (154, 88)
# Red dot coordinates: (153, 88)
# Red dot coordinates: (147, 94)
# Red dot coordinates: (146, 94)
# Red dot coordinates: (144, 96)
# Red dot coordinates: (144, 97)
# Red dot coordinates: (143, 98)
# Red dot coordinates: (143, 124)
# Red dot coordinates: (144, 125)
# Red dot coordinates: (144, 127)
# Red dot coordinates: (143, 128)
# Red dot coordinates: (143, 148)
# Red dot coordinates: (142, 149)
# Red dot coordinates: (142, 160)
# Red dot coordinates: (141, 161)
# Red dot coordinates: (141, 183)
# Red dot coordinates: (142, 184)
# Red dot coordinates: (142, 187)
# Red dot coordinates: (141, 188)
# Red dot coordinates: (141, 230)
# Red dot coordinates: (142, 231)
# Red dot coordinates: (142, 233)
# Red dot coordinates: (143, 234)
# Red dot coordinates: (143, 270)
# Red dot coordinates: (144, 271)
# Red dot coordinates: (144, 278)
# Red dot coordinates: (145, 279)
# Red dot coordinates: (145, 289)
# Red dot coordinates: (146, 290)
# Red dot coordinates: (146, 295)
# Red dot coordinates: (147, 296)
# Red dot coordinates: (147, 305)
# Red dot coordinates: (148, 306)
# Red dot coordinates: (148, 309)
# Red dot coordinates: (147, 310)
# Red dot coordinates: (147, 312)
# Red dot coordinates: (146, 313)
# Red dot coordinates: (146, 315)
# Red dot coordinates: (145, 316)
# Red dot coordinates: (145, 317)
# Red dot coordinates: (142, 320)
# Red dot coordinates: (141, 320)
# Red dot coordinates: (139, 322)
# Red dot coordinates: (138, 322)
# Red dot coordinates: (128, 332)
# Red dot coordinates: (128, 333)
# Red dot coordinates: (122, 339)
# Red dot coordinates: (121, 339)
# Red dot coordinates: (117, 343)
# Red dot coordinates: (116, 343)
# Red dot coordinates: (113, 346)
# Red dot coordinates: (112, 346)
# Red dot coordinates: (107, 351)
# Red dot coordinates: (106, 351)
# Red dot coordinates: (103, 354)
# Red dot coordinates: (102, 354)
# Red dot coordinates: (101, 355)
# Red dot coordinates: (100, 355)
# Red dot coordinates: (99, 356)
# Red dot coordinates: (98, 356)
# Red dot coordinates: (97, 357)
# Red dot coordinates: (96, 357)
# Red dot coordinates: (95, 358)
# Red dot coordinates: (94, 358)
# Red dot coordinates: (92, 360)
# Red dot coordinates: (91, 360)
# Red dot coordinates: (90, 361)
# Red dot coordinates: (85, 361)
# Red dot coordinates: (84, 362)
# Red dot coordinates: (83, 362)
# Red dot coordinates: (83, 363)
# Red dot coordinates: (82, 364)
# Red dot coordinates: (82, 366)
# Red dot coordinates: (83, 367)
# Red dot coordinates: (83, 372)
# Red dot coordinates: (84, 373)
# Red dot coordinates: (84, 377)
# Red dot coordinates: (85, 378)
# Red dot coordinates: (85, 382)
# Red dot coordinates: (86, 383)
# Red dot coordinates: (86, 388)
# Red dot coordinates: (87, 389)
# Red dot coordinates: (87, 395)
# Red dot coordinates: (88, 396)
# Red dot coordinates: (88, 399)
# Red dot coordinates: (89, 400)
# Red dot coordinates: (89, 417)
# Red dot coordinates: (90, 418)
# Red dot coordinates: (90, 423)
# Red dot coordinates: (89, 424)
# Red dot coordinates: (89, 428)
# Red dot coordinates: (82, 435)
# Red dot coordinates: (81, 435)
# Red dot coordinates: (80, 436)
# Red dot coordinates: (79, 436)
# Red dot coordinates: (76, 439)
# Red dot coordinates: (75, 439)
# Red dot coordinates: (74, 440)
# Red dot coordinates: (74, 441)
# Red dot coordinates: (70, 445)
# Red dot coordinates: (69, 445)
# Red dot coordinates: (67, 447)
# Red dot coordinates: (66, 447)
# Red dot coordinates: (65, 448)
# Red dot coordinates: (64, 448)
# Red dot coordinates: (63, 449)
# Red dot coordinates: (59, 449)
# Red dot coordinates: (57, 447)
# Red dot coordinates: (57, 440)
# Red dot coordinates: (58, 439)
# Red dot coordinates: (58, 438)
# Red dot coordinates: (68, 428)
# Red dot coordinates: (69, 428)
# Red dot coordinates: (72, 425)
# Red dot coordinates: (73, 425)
# Red dot coordinates: (74, 424)
# Red dot coordinates: (75, 424)
# Red dot coordinates: (76, 423)
# Red dot coordinates: (76, 404)
# Red dot coordinates: (75, 403)
# Red dot coordinates: (75, 397)
# Red dot coordinates: (74, 396)
# Red dot coordinates: (74, 391)
# Red dot coordinates: (73, 390)
# Red dot coordinates: (73, 387)
# Red dot coordinates: (72, 386)
# Red dot coordinates: (72, 382)
# Red dot coordinates: (71, 381)
# Red dot coordinates: (71, 376)
# Red dot coordinates: (70, 375)
# Red dot coordinates: (70, 369)
# Red dot coordinates: (69, 368)
# Red dot coordinates: (69, 358)
# Red dot coordinates: (71, 356)
# Red dot coordinates: (71, 355)
# Red dot coordinates: (74, 352)
# Red dot coordinates: (75, 352)
# Red dot coordinates: (77, 350)
# Red dot coordinates: (79, 350)
# Red dot coordinates: (80, 349)
# Red dot coordinates: (81, 349)
# Red dot coordinates: (82, 348)
# Red dot coordinates: (85, 348)
# Red dot coordinates: (86, 347)
# Red dot coordinates: (87, 347)
# Red dot coordinates: (88, 346)
# Red dot coordinates: (89, 346)
# Red dot coordinates: (90, 345)
# Red dot coordinates: (91, 345)
# Red dot coordinates: (93, 343)
# Red dot coordinates: (94, 343)
# Red dot coordinates: (95, 342)
# Red dot coordinates: (96, 342)
# Red dot coordinates: (97, 341)
# Red dot coordinates: (98, 341)
# Red dot coordinates: (99, 340)
# Red dot coordinates: (100, 340)
# Red dot coordinates: (105, 335)
# Red dot coordinates: (106, 335)
# Red dot coordinates: (109, 332)
# Red dot coordinates: (110, 332)
# Red dot coordinates: (114, 328)
# Red dot coordinates: (115, 328)
# Red dot coordinates: (120, 323)
# Red dot coordinates: (120, 322)
# Red dot coordinates: (129, 313)
# Red dot coordinates: (130, 313)
# Red dot coordinates: (134, 309)
# Red dot coordinates: (134, 306)
# Red dot coordinates: (133, 305)
# Red dot coordinates: (133, 287)
# Red dot coordinates: (132, 286)
# Red dot coordinates: (132, 278)
# Red dot coordinates: (131, 277)
# Red dot coordinates: (131, 270)
# Red dot coordinates: (130, 269)
# Red dot coordinates: (130, 242)
# Red dot coordinates: (129, 241)
# Red dot coordinates: (129, 233)
# Red dot coordinates: (128, 232)
# Red dot coordinates: (128, 160)
# Red dot coordinates: (129, 159)
# Red dot coordinates: (129, 146)
# Red dot coordinates: (130, 145)
# Red dot coordinates: (130, 96)
# Red dot coordinates: (131, 95)
# Red dot coordinates: (131, 93)
# Red dot coordinates: (132, 92)
# Red dot coordinates: (132, 91)
# Red dot coordinates: (133, 90)
# Red dot coordinates: (133, 89)
# Red dot coordinates: (138, 84)
# Red dot coordinates: (139, 84)
# Red dot coordinates: (145, 78)
# Red dot coordinates: (146, 78)
# Red dot coordinates: (148, 76)
# Red dot coordinates: (149, 76)
# Red dot coordinates: (151, 74)
# Red dot coordinates: (152, 74)
# Red dot coordinates: (153, 73)
# Red dot coordinates: (154, 73)
# Red dot coordinates: (157, 70)
# Red dot coordinates: (158, 70)
# Red dot coordinates: (159, 69)
# Red dot coordinates: (161, 69)
# Red dot coordinates: (164, 66)
# Red dot coordinates: (165, 66)
# Red dot coordinates: (168, 63)
# Red dot coordinates: (169, 63)
# Red dot coordinates: (171, 61)
# Red dot coordinates: (172, 61)
# Red dot coordinates: (175, 58)
# Red dot coordinates: (176, 58)
# Red dot coordinates: (178, 56)
# Red dot coordinates: (179, 56)
# Red dot coordinates: (182, 53)
# Red dot coordinates: (183, 53)
# Red dot coordinates: (184, 52)
# Red dot coordinates: (185, 52)
# Red dot coordinates: (186, 51)
# Red dot coordinates: (192, 51)
# Red dot coordinates: (197, 56)
# Red dot coordinates: (197, 57)
# Red dot coordinates: (198, 57)
# Red dot coordinates: (200, 59)
# Red dot coordinates: (201, 59)
# Red dot coordinates: (202, 60)
# Red dot coordinates: (203, 60)
# Red dot coordinates: (204, 61)
# Red dot coordinates: (205, 61)
# Red dot coordinates: (206, 62)
# Red dot coordinates: (208, 62)
# Red dot coordinates: (209, 63)
# Red dot coordinates: (212, 63)
# Red dot coordinates: (213, 64)
# Red dot coordinates: (215, 64)
# Red dot coordinates: (216, 65)
# Red dot coordinates: (217, 65)
# Red dot coordinates: (218, 66)
# Red dot coordinates: (219, 66)
# Red dot coordinates: (221, 68)
# Red dot coordinates: (221, 69)
# Red dot coordinates: (222, 70)
# Red dot coordinates: (222, 73)
# Red dot coordinates: (223, 74)
# Red dot coordinates: (223, 80)
# Red dot coordinates: (224, 81)
# Red dot coordinates: (224, 86)
# Red dot coordinates: (225, 87)
# Red dot coordinates: (225, 94)
# Red dot coordinates: (226, 95)
# Red dot coordinates: (226, 99)
# Red dot coordinates: (227, 100)
# Red dot coordinates: (227, 104)
# Red dot coordinates: (228, 105)
# Red dot coordinates: (228, 108)
# Red dot coordinates: (229, 109)
# Red dot coordinates: (229, 111)
# Red dot coordinates: (230, 112)
# Red dot coordinates: (230, 114)
# Red dot coordinates: (231, 115)
# Red dot coordinates: (231, 119)
# Red dot coordinates: (232, 120)
# Red dot coordinates: (232, 122)
# Red dot coordinates: (233, 123)
# Red dot coordinates: (233, 124)
# Red dot coordinates: (234, 125)
# Red dot coordinates: (234, 126)
# Red dot coordinates: (235, 127)
# Red dot coordinates: (235, 128)
# Red dot coordinates: (239, 128)
# Red dot coordinates: (240, 129)
# Red dot coordinates: (247, 129)
# Red dot coordinates: (248, 130)
# Red dot coordinates: (255, 130)
# Red dot coordinates: (256, 131)
# Red dot coordinates: (267, 131)
# Red dot coordinates: (268, 132)
# Red dot coordinates: (273, 132)
# Red dot coordinates: (274, 133)
# Red dot coordinates: (282, 133)
# Red dot coordinates: (283, 134)
# Red dot coordinates: (286, 134)
# Red dot coordinates: (287, 135)
# Red dot coordinates: (292, 135)
# Red dot coordinates: (293, 136)
# Red dot coordinates: (300, 136)
# Red dot coordinates: (301, 137)
# Red dot coordinates: (307, 137)
# Red dot coordinates: (308, 138)
# Red dot coordinates: (315, 138)
# Red dot coordinates: (316, 139)
# Red dot coordinates: (320, 139)
# Red dot coordinates: (321, 140)
# Red dot coordinates: (328, 140)
# Red dot coordinates: (329, 141)
# Red dot coordinates: (331, 141)
# Red dot coordinates: (332, 142)
# Red dot coordinates: (334, 142)
# Red dot coordinates: (335, 143)
# Red dot coordinates: (340, 143)
# Red dot coordinates: (341, 144)
# Red dot coordinates: (355, 144)
# Red dot coordinates: (356, 145)
# Red dot coordinates: (361, 145)
# Red dot coordinates: (362, 146)
# Red dot coordinates: (367, 146)
# Red dot coordinates: (368, 147)
# Red dot coordinates: (370, 147)
# Red dot coordinates: (371, 148)
# Red dot coordinates: (373, 148)
# Red dot coordinates: (374, 149)
# Red dot coordinates: (376, 149)
# Red dot coordinates: (377, 150)
# Red dot coordinates: (380, 150)
# Red dot coordinates: (381, 149)
# Red dot coordinates: (386, 149)
# Red dot coordinates: (387, 148)
# Red dot coordinates: (389, 148)
# Red dot coordinates: (390, 147)
# Red dot coordinates: (391, 147)
# Red dot coordinates: (395, 143)
# Red dot coordinates: (396, 143)
# Red dot coordinates: (397, 142)
# Red dot coordinates: (397, 141)
# Red dot coordinates: (399, 139)
# Red dot coordinates: (400, 139)
# Red dot coordinates: (403, 136)
# Red dot coordinates: (403, 124)
# Red dot coordinates: (404, 123)
# Red dot coordinates: (404, 112)
# Red dot coordinates: (405, 111)
# Red dot coordinates: (405, 98)
# Red dot coordinates: (404, 97)
# Red dot coordinates: (404, 96)
# Red dot coordinates: (402, 94)
# Red dot coordinates: (402, 88)
# Red dot coordinates: (405, 85)
# Red dot coordinates: (405, 84)
# Red dot coordinates: (407, 82)
# Red dot coordinates: (408, 82)
# Red dot coordinates: (410, 80)
# Red dot coordinates: (411, 80)
# Red dot coordinates: (412, 79)
# Red dot coordinates: (413, 79)
# Red dot coordinates: (414, 78)
# Red dot coordinates: (416, 78)
# Red dot coordinates: (417, 77)
# Red dot coordinates: (419, 77)
# Red dot coordinates: (420, 76)
# Red dot coordinates: (421, 76)
# Red dot coordinates: (422, 75)
# Red dot coordinates: (424, 75)
# Red dot coordinates: (425, 74)
# Red dot coordinates: (429, 74)
# Red dot coordinates: (430, 73)
# Red dot coordinates: (435, 73)
# Red dot coordinates: (436, 72)
# Red dot coordinates: (440, 72)
# Red dot coordinates: (441, 71)
# Red dot coordinates: (447, 71)
# Red dot coordinates: (448, 70)
# Red dot coordinates: (452, 70)
# Red dot coordinates: (453, 69)
# Red dot coordinates: (458, 69)
# Red dot coordinates: (459, 68)
# Red dot coordinates: (464, 68)
# Red dot coordinates: (465, 67)
# Red dot coordinates: (473, 67)
# Red dot coordinates: (474, 66)
# Red dot coordinates: (511, 66)
# Red dot coordinates: (512, 65)
# Red dot coordinates: (525, 65)
# Red dot coordinates: (526, 64)
# Red dot coordinates: (536, 64)
# Red dot coordinates: (537, 63)
# Red dot coordinates: (543, 63)
# Red dot coordinates: (544, 64)
# Red dot coordinates: (545, 64)
# Red dot coordinates: (546, 65)
# Red dot coordinates: (546, 68)
# Red dot coordinates: (546, 65)
# Red dot coordinates: (545, 64)
# Red dot coordinates: (544, 64)
# Red dot coordinates: (543, 63)
# Red dot coordinates: (537, 63)
# Red dot coordinates: (536, 64)
# Red dot coordinates: (526, 64)
# Red dot coordinates: (525, 65)
# Red dot coordinates: (512, 65)
# Red dot coordinates: (511, 66)
# Red dot coordinates: (474, 66)
# Red dot coordinates: (473, 67)
# Red dot coordinates: (465, 67)
# Red dot coordinates: (464, 68)
# Red dot coordinates: (459, 68)
# Red dot coordinates: (458, 69)
# Red dot coordinates: (453, 69)
# Red dot coordinates: (452, 70)
# Red dot coordinates: (448, 70)
# Red dot coordinates: (447, 71)
# Red dot coordinates: (441, 71)
# Red dot coordinates: (440, 72)
# Red dot coordinates: (436, 72)
# Red dot coordinates: (435, 73)
# Red dot coordinates: (430, 73)
# Red dot coordinates: (429, 74)
# Red dot coordinates: (425, 74)
# Red dot coordinates: (424, 75)
# Red dot coordinates: (422, 75)
# Red dot coordinates: (421, 76)
# Red dot coordinates: (420, 76)
# Red dot coordinates: (419, 77)
# Red dot coordinates: (417, 77)
# Red dot coordinates: (416, 78)
# Red dot coordinates: (414, 78)
# Red dot coordinates: (413, 79)
# Red dot coordinates: (412, 79)
# Red dot coordinates: (411, 80)
# Red dot coordinates: (410, 80)
# Red dot coordinates: (409, 81)
# Red dot coordinates: (408, 81)
# Red dot coordinates: (403, 86)
# Red dot coordinates: (403, 87)
# Red dot coordinates: (402, 88)
# Red dot coordinates: (402, 94)
# Red dot coordinates: (403, 95)
# Red dot coordinates: (403, 96)
# Red dot coordinates: (405, 98)
# Red dot coordinates: (405, 111)
# Red dot coordinates: (404, 112)
# Red dot coordinates: (404, 123)
# Red dot coordinates: (403, 124)
# Red dot coordinates: (403, 135)
# Red dot coordinates: (394, 144)
# Red dot coordinates: (393, 144)
# Red dot coordinates: (389, 148)
# Red dot coordinates: (387, 148)
# Red dot coordinates: (386, 149)
# Red dot coordinates: (381, 149)
# Red dot coordinates: (380, 150)
# Red dot coordinates: (377, 150)
# Red dot coordinates: (376, 149)
# Red dot coordinates: (374, 149)
# Red dot coordinates: (373, 148)
# Red dot coordinates: (371, 148)
# Red dot coordinates: (370, 147)
# Red dot coordinates: (368, 147)
# Red dot coordinates: (367, 146)
# Red dot coordinates: (362, 146)
# Red dot coordinates: (361, 145)
# Red dot coordinates: (356, 145)
# Red dot coordinates: (355, 144)
# Red dot coordinates: (341, 144)
# Red dot coordinates: (340, 143)
# Red dot coordinates: (335, 143)
# Red dot coordinates: (334, 142)
# Red dot coordinates: (332, 142)
# Red dot coordinates: (331, 141)
# Red dot coordinates: (329, 141)
# Red dot coordinates: (328, 140)
# Red dot coordinates: (321, 140)
# Red dot coordinates: (320, 139)
# Red dot coordinates: (316, 139)
# Red dot coordinates: (315, 138)
# Red dot coordinates: (308, 138)
# Red dot coordinates: (307, 137)
# Red dot coordinates: (301, 137)
# Red dot coordinates: (300, 136)
# Red dot coordinates: (293, 136)
# Red dot coordinates: (292, 135)
# Red dot coordinates: (287, 135)
# Red dot coordinates: (286, 134)
# Red dot coordinates: (283, 134)
# Red dot coordinates: (282, 133)
# Red dot coordinates: (274, 133)
# Red dot coordinates: (273, 132)
# Red dot coordinates: (268, 132)
# Red dot coordinates: (267, 131)
# Red dot coordinates: (256, 131)
# Red dot coordinates: (255, 130)
# Red dot coordinates: (248, 130)
# Red dot coordinates: (247, 129)
# Red dot coordinates: (240, 129)
# Red dot coordinates: (239, 128)
# Red dot coordinates: (236, 128)
# Red dot coordinates: (234, 126)
# Red dot coordinates: (234, 125)
# Red dot coordinates: (233, 124)
# Red dot coordinates: (233, 123)
# Red dot coordinates: (232, 122)
# Red dot coordinates: (232, 120)
# Red dot coordinates: (231, 119)
# Red dot coordinates: (231, 115)
# Red dot coordinates: (230, 114)
# Red dot coordinates: (230, 112)
# Red dot coordinates: (229, 111)
# Red dot coordinates: (229, 109)
# Red dot coordinates: (228, 108)
# Red dot coordinates: (228, 105)
# Red dot coordinates: (227, 104)
# Red dot coordinates: (227, 100)
# Red dot coordinates: (226, 99)
# Red dot coordinates: (226, 95)
# Red dot coordinates: (225, 94)
# Red dot coordinates: (225, 87)
# Red dot coordinates: (224, 86)
# Red dot coordinates: (224, 81)
# Red dot coordinates: (223, 80)
# Red dot coordinates: (223, 74)
# Red dot coordinates: (222, 73)
# Red dot coordinates: (222, 70)
# Red dot coordinates: (221, 69)
# Red dot coordinates: (221, 68)
# Red dot coordinates: (219, 66)
# Red dot coordinates: (218, 66)
# Red dot coordinates: (217, 65)
# Red dot coordinates: (216, 65)
# Red dot coordinates: (215, 64)
# Red dot coordinates: (213, 64)
# Red dot coordinates: (212, 63)
# Red dot coordinates: (209, 63)
# Red dot coordinates: (208, 62)
# Red dot coordinates: (206, 62)
# Red dot coordinates: (205, 61)
# Red dot coordinates: (204, 61)
# Red dot coordinates: (203, 60)
# Red dot coordinates: (202, 60)
# Red dot coordinates: (200, 58)
# Red dot coordinates: (199, 58)
# Red dot coordinates: (196, 55)
# Red dot coordinates: (196, 54)
# Red dot coordinates: (194, 52)
# Red dot coordinates: (193, 52)
# Red dot coordinates: (192, 51)
# Red dot coordinates: (186, 51)
# Red dot coordinates: (185, 52)
# Red dot coordinates: (184, 52)
# Red dot coordinates: (183, 53)
# Red dot coordinates: (182, 53)
# Red dot coordinates: (181, 54)
# Red dot coordinates: (180, 54)
# Red dot coordinates: (177, 57)
# Red dot coordinates: (176, 57)
# Red dot coordinates: (174, 59)
# Red dot coordinates: (173, 59)
# Red dot coordinates: (170, 62)
# Red dot coordinates: (169, 62)
# Red dot coordinates: (167, 64)
# Red dot coordinates: (166, 64)
# Red dot coordinates: (163, 67)
# Red dot coordinates: (162, 67)
# Red dot coordinates: (160, 69)
# Red dot coordinates: (159, 69)
# Red dot coordinates: (158, 70)
# Red dot coordinates: (157, 70)
# Red dot coordinates: (156, 71)
# Red dot coordinates: (155, 71)
# Red dot coordinates: (152, 74)
# Red dot coordinates: (151, 74)
# Red dot coordinates: (150, 75)
# Red dot coordinates: (149, 75)
# Red dot coordinates: (147, 77)
# Red dot coordinates: (146, 77)
# Red dot coordinates: (144, 79)
# Red dot coordinates: (143, 79)
# Red dot coordinates: (137, 85)
# Red dot coordinates: (136, 85)
# Red dot coordinates: (134, 87)
# Red dot coordinates: (134, 88)
# Red dot coordinates: (133, 89)
# Red dot coordinates: (133, 90)
# Red dot coordinates: (132, 91)
# Red dot coordinates: (132, 92)
# Red dot coordinates: (131, 93)
# Red dot coordinates: (131, 95)
# Red dot coordinates: (130, 96)
# Red dot coordinates: (130, 145)
# Red dot coordinates: (129, 146)
# Red dot coordinates: (129, 159)
# Red dot coordinates: (128, 160)
# Red dot coordinates: (128, 232)
# Red dot coordinates: (129, 233)
# Red dot coordinates: (129, 241)
# Red dot coordinates: (130, 242)
# Red dot coordinates: (130, 269)
# Red dot coordinates: (131, 270)
# Red dot coordinates: (131, 277)
# Red dot coordinates: (132, 278)
# Red dot coordinates: (132, 286)
# Red dot coordinates: (133, 287)
# Red dot coordinates: (133, 305)
# Red dot coordinates: (134, 306)
# Red dot coordinates: (134, 308)
# Red dot coordinates: (128, 314)
# Red dot coordinates: (127, 314)
# Red dot coordinates: (121, 320)
# Red dot coordinates: (121, 321)
# Red dot coordinates: (113, 329)
# Red dot coordinates: (112, 329)
# Red dot coordinates: (108, 333)
# Red dot coordinates: (107, 333)
# Red dot coordinates: (104, 336)
# Red dot coordinates: (103, 336)
# Red dot coordinates: (98, 341)
# Red dot coordinates: (97, 341)
# Red dot coordinates: (96, 342)
# Red dot coordinates: (95, 342)
# Red dot coordinates: (94, 343)
# Red dot coordinates: (93, 343)
# Red dot coordinates: (92, 344)
# Red dot coordinates: (91, 344)
# Red dot coordinates: (89, 346)
# Red dot coordinates: (88, 346)
# Red dot coordinates: (87, 347)
# Red dot coordinates: (86, 347)
# Red dot coordinates: (85, 348)
# Red dot coordinates: (82, 348)
# Red dot coordinates: (81, 349)
# Red dot coordinates: (80, 349)
# Red dot coordinates: (79, 350)
# Red dot coordinates: (77, 350)
# Red dot coordinates: (76, 351)
# Red dot coordinates: (75, 351)
# Red dot coordinates: (73, 353)
# Red dot coordinates: (72, 353)
# Red dot coordinates: (72, 354)
# Red dot coordinates: (70, 356)
# Red dot coordinates: (70, 357)
# Red dot coordinates: (69, 358)
# Red dot coordinates: (69, 368)
# Red dot coordinates: (70, 369)
# Red dot coordinates: (70, 375)
# Red dot coordinates: (71, 376)
# Red dot coordinates: (71, 381)
# Red dot coordinates: (72, 382)
# Red dot coordinates: (72, 386)
# Red dot coordinates: (73, 387)
# Red dot coordinates: (73, 390)
# Red dot coordinates: (74, 391)
# Red dot coordinates: (74, 396)
# Red dot coordinates: (75, 397)
# Red dot coordinates: (75, 403)
# Red dot coordinates: (76, 404)
# Red dot coordinates: (76, 422)
# Red dot coordinates: (73, 425)
# Red dot coordinates: (72, 425)
# Red dot coordinates: (71, 426)
# Red dot coordinates: (70, 426)
# Red dot coordinates: (67, 429)
# Red dot coordinates: (66, 429)
# Red dot coordinates: (59, 436)
# Red dot coordinates: (59, 437)
# Red dot coordinates: (58, 438)
# Red dot coordinates: (58, 439)
# Red dot coordinates: (57, 440)
# Red dot coordinates: (57, 447)
# Red dot coordinates: (58, 448)
# Red dot coordinates: (58, 449)
# Red dot coordinates: (64, 449)
# Red dot coordinates: (66, 447)
# Red dot coordinates: (67, 447)
# Red dot coordinates: (68, 446)
# Red dot coordinates: (69, 446)
# Red dot coordinates: (71, 444)
# Red dot coordinates: (72, 444)
# Red dot coordinates: (73, 443)
# Red dot coordinates: (73, 442)
# Red dot coordinates: (77, 438)
# Red dot coordinates: (78, 438)
# Red dot coordinates: (81, 435)
# Red dot coordinates: (82, 435)
# Red dot coordinates: (83, 434)
# Red dot coordinates: (84, 434)
# Red dot coordinates: (88, 430)
# Red dot coordinates: (88, 429)
# Red dot coordinates: (89, 428)
# Red dot coordinates: (89, 424)
# Red dot coordinates: (90, 423)
# Red dot coordinates: (90, 418)
# Red dot coordinates: (89, 417)
# Red dot coordinates: (89, 400)
# Red dot coordinates: (88, 399)
# Red dot coordinates: (88, 396)
# Red dot coordinates: (87, 395)
# Red dot coordinates: (87, 389)
# Red dot coordinates: (86, 388)
# Red dot coordinates: (86, 383)
# Red dot coordinates: (85, 382)
# Red dot coordinates: (85, 378)
# Red dot coordinates: (84, 377)
# Red dot coordinates: (84, 373)
# Red dot coordinates: (83, 372)
# Red dot coordinates: (83, 367)
# Red dot coordinates: (82, 366)
# Red dot coordinates: (82, 364)
# Red dot coordinates: (85, 361)
# Red dot coordinates: (90, 361)
# Red dot coordinates: (91, 360)
# Red dot coordinates: (93, 360)
# Red dot coordinates: (96, 357)
# Red dot coordinates: (97, 357)
# Red dot coordinates: (98, 356)
# Red dot coordinates: (99, 356)
# Red dot coordinates: (100, 355)
# Red dot coordinates: (101, 355)
# Red dot coordinates: (102, 354)
# Red dot coordinates: (103, 354)
# Red dot coordinates: (104, 353)
# Red dot coordinates: (105, 353)
# Red dot coordinates: (110, 348)
# Red dot coordinates: (111, 348)
# Red dot coordinates: (114, 345)
# Red dot coordinates: (115, 345)
# Red dot coordinates: (118, 342)
# Red dot coordinates: (119, 342)
# Red dot coordinates: (123, 338)
# Red dot coordinates: (124, 338)
# Red dot coordinates: (124, 337)
# Red dot coordinates: (126, 335)
# Red dot coordinates: (127, 335)
# Red dot coordinates: (127, 334)
# Red dot coordinates: (140, 321)
# Red dot coordinates: (141, 321)
# Red dot coordinates: (143, 319)
# Red dot coordinates: (144, 319)
# Red dot coordinates: (144, 318)
# Red dot coordinates: (145, 317)
# Red dot coordinates: (145, 316)
# Red dot coordinates: (146, 315)
# Red dot coordinates: (146, 313)
# Red dot coordinates: (147, 312)
# Red dot coordinates: (147, 310)
# Red dot coordinates: (148, 309)
# Red dot coordinates: (148, 306)
# Red dot coordinates: (147, 305)
# Red dot coordinates: (147, 296)
# Red dot coordinates: (146, 295)
# Red dot coordinates: (146, 290)
# Red dot coordinates: (145, 289)
# Red dot coordinates: (145, 279)
# Red dot coordinates: (144, 278)
# Red dot coordinates: (144, 271)
# Red dot coordinates: (143, 270)
# Red dot coordinates: (143, 234)
# Red dot coordinates: (142, 233)
# Red dot coordinates: (142, 231)
# Red dot coordinates: (141, 230)
# Red dot coordinates: (141, 188)
# Red dot coordinates: (142, 187)
# Red dot coordinates: (142, 184)
# Red dot coordinates: (141, 183)
# Red dot coordinates: (141, 161)
# Red dot coordinates: (142, 160)
# Red dot coordinates: (142, 149)
# Red dot coordinates: (143, 148)
# Red dot coordinates: (143, 128)
# Red dot coordinates: (144, 127)
# Red dot coordinates: (144, 125)
# Red dot coordinates: (143, 124)
# Red dot coordinates: (143, 98)
# Red dot coordinates: (148, 93)
# Red dot coordinates: (149, 93)
# Red dot coordinates: (155, 87)
# Red dot coordinates: (156, 87)
# Red dot coordinates: (157, 86)
# Red dot coordinates: (158, 86)
# Red dot coordinates: (160, 84)
# Red dot coordinates: (161, 84)
# Red dot coordinates: (163, 82)
# Red dot coordinates: (164, 82)
# Red dot coordinates: (165, 81)
# Red dot coordinates: (166, 81)
# Red dot coordinates: (167, 80)
# Red dot coordinates: (168, 80)
# Red dot coordinates: (169, 79)
# Red dot coordinates: (170, 79)
# Red dot coordinates: (174, 75)
# Red dot coordinates: (175, 75)
# Red dot coordinates: (177, 73)
# Red dot coordinates: (178, 73)
# Red dot coordinates: (181, 70)
# Red dot coordinates: (182, 70)
# Red dot coordinates: (184, 68)
# Red dot coordinates: (185, 68)
# Red dot coordinates: (187, 66)
# Red dot coordinates: (188, 66)
# Red dot coordinates: (191, 69)
# Red dot coordinates: (192, 69)
# Red dot coordinates: (194, 71)
# Red dot coordinates: (195, 71)
# Red dot coordinates: (198, 74)
# Red dot coordinates: (200, 74)
# Red dot coordinates: (201, 75)
# Red dot coordinates: (204, 75)
# Red dot coordinates: (205, 76)
# Red dot coordinates: (208, 76)
# Red dot coordinates: (210, 78)
# Red dot coordinates: (210, 81)
# Red dot coordinates: (211, 82)
# Red dot coordinates: (211, 91)
# Red dot coordinates: (212, 92)
# Red dot coordinates: (212, 97)
# Red dot coordinates: (213, 98)
# Red dot coordinates: (213, 102)
# Red dot coordinates: (214, 103)
# Red dot coordinates: (214, 106)
# Red dot coordinates: (215, 107)
# Red dot coordinates: (215, 110)
# Red dot coordinates: (216, 111)
# Red dot coordinates: (216, 114)
# Red dot coordinates: (217, 115)
# Red dot coordinates: (217, 117)
# Red dot coordinates: (218, 118)
# Red dot coordinates: (218, 122)
# Red dot coordinates: (219, 123)
# Red dot coordinates: (219, 125)
# Red dot coordinates: (220, 126)
# Red dot coordinates: (220, 127)
# Red dot coordinates: (221, 128)
# Red dot coordinates: (221, 129)
# Red dot coordinates: (222, 130)
# Red dot coordinates: (222, 131)
# Red dot coordinates: (223, 132)
# Red dot coordinates: (225, 132)
# Red dot coordinates: (226, 133)
# Red dot coordinates: (226, 139)
# Red dot coordinates: (227, 140)
# Red dot coordinates: (227, 141)
# Red dot coordinates: (238, 141)
# Red dot coordinates: (239, 142)
# Red dot coordinates: (244, 142)
# Red dot coordinates: (245, 143)
# Red dot coordinates: (254, 143)
# Red dot coordinates: (255, 144)
# Red dot coordinates: (262, 144)
# Red dot coordinates: (263, 145)
# Red dot coordinates: (273, 145)
# Red dot coordinates: (274, 146)
# Red dot coordinates: (280, 146)
# Red dot coordinates: (281, 147)
# Red dot coordinates: (283, 147)
# Red dot coordinates: (284, 148)
# Red dot coordinates: (286, 148)
# Red dot coordinates: (287, 149)
# Red dot coordinates: (295, 149)
# Red dot coordinates: (296, 150)
# Red dot coordinates: (307, 150)
# Red dot coordinates: (308, 151)
# Red dot coordinates: (314, 151)
# Red dot coordinates: (315, 152)
# Red dot coordinates: (318, 152)
# Red dot coordinates: (319, 153)
# Red dot coordinates: (324, 153)
# Red dot coordinates: (325, 154)
# Red dot coordinates: (327, 154)
# Red dot coordinates: (328, 155)
# Red dot coordinates: (332, 155)
# Red dot coordinates: (333, 156)
# Red dot coordinates: (349, 156)
# Red dot coordinates: (350, 157)
# Red dot coordinates: (353, 157)
# Red dot coordinates: (354, 158)
# Red dot coordinates: (359, 158)
# Red dot coordinates: (360, 159)
# Red dot coordinates: (365, 159)
# Red dot coordinates: (366, 160)
# Red dot coordinates: (367, 160)
# Red dot coordinates: (368, 161)
# Red dot coordinates: (370, 161)
# Red dot coordinates: (371, 162)
# Red dot coordinates: (372, 162)
# Red dot coordinates: (373, 163)
# Red dot coordinates: (387, 163)
# Red dot coordinates: (388, 162)
# Red dot coordinates: (390, 162)
# Red dot coordinates: (391, 161)
# Red dot coordinates: (394, 161)
# Red dot coordinates: (395, 160)
# Red dot coordinates: (396, 160)
# Red dot coordinates: (397, 159)
# Red dot coordinates: (398, 159)
# Red dot coordinates: (402, 155)
# Red dot coordinates: (403, 155)
# Red dot coordinates: (404, 154)
# Red dot coordinates: (404, 153)
# Red dot coordinates: (408, 149)
# Red dot coordinates: (409, 149)
# Red dot coordinates: (416, 142)
# Red dot coordinates: (416, 140)
# Red dot coordinates: (418, 138)
# Red dot coordinates: (418, 135)
# Red dot coordinates: (417, 134)
# Red dot coordinates: (417, 120)
# Red dot coordinates: (418, 119)
# Red dot coordinates: (418, 105)
# Red dot coordinates: (419, 104)
# Red dot coordinates: (419, 99)
# Red dot coordinates: (418, 98)
# Red dot coordinates: (418, 92)
# Red dot coordinates: (420, 90)
# Red dot coordinates: (422, 90)
# Red dot coordinates: (423, 89)
# Red dot coordinates: (425, 89)
# Red dot coordinates: (426, 88)
# Red dot coordinates: (427, 88)
# Red dot coordinates: (428, 87)
# Red dot coordinates: (432, 87)
# Red dot coordinates: (433, 86)
# Red dot coordinates: (439, 86)
# Red dot coordinates: (440, 85)
# Red dot coordinates: (444, 85)
# Red dot coordinates: (445, 84)
# Red dot coordinates: (449, 84)
# Red dot coordinates: (450, 83)
# Red dot coordinates: (453, 83)
# Red dot coordinates: (454, 82)
# Red dot coordinates: (460, 82)
# Red dot coordinates: (461, 81)
# Red dot coordinates: (468, 81)
# Red dot coordinates: (469, 80)
# Red dot coordinates: (481, 80)
# Red dot coordinates: (482, 79)
# Red dot coordinates: (515, 79)
# Red dot coordinates: (516, 78)
# Red dot coordinates: (528, 78)
# Red dot coordinates: (529, 77)
# Red dot coordinates: (535, 77)
# Red dot coordinates: (536, 76)
# Red dot coordinates: (544, 76)
# Red dot coordinates: (545, 77)
# Red dot coordinates: (547, 77)
# Red dot coordinates: (548, 78)
# Red dot coordinates: (551, 78)
# Red dot coordinates: (552, 79)
# Red dot coordinates: (553, 79)
# Red dot coordinates: (554, 80)
# Red dot coordinates: (555, 80)
# Red dot coordinates: (556, 81)
# Red dot coordinates: (557, 81)
# Red dot coordinates: (558, 82)
# Red dot coordinates: (559, 82)
# Red dot coordinates: (561, 84)
# Red dot coordinates: (562, 84)
# Red dot coordinates: (564, 86)
# Red dot coordinates: (566, 86)
# Red dot coordinates: (567, 87)
# Red dot coordinates: (568, 87)
# Red dot coordinates: (570, 89)
# Red dot coordinates: (572, 89)
# Red dot coordinates: (573, 90)
# Red dot coordinates: (575, 90)
# Red dot coordinates: (576, 91)
# Red dot coordinates: (577, 91)
# Red dot coordinates: (578, 92)
# Red dot coordinates: (579, 92)
# Red dot coordinates: (580, 93)
# Red dot coordinates: (581, 93)
# Red dot coordinates: (582, 94)
# Red dot coordinates: (584, 94)
# Red dot coordinates: (585, 95)
# Red dot coordinates: (586, 95)
# Red dot coordinates: (587, 96)
# Red dot coordinates: (588, 96)
# Red dot coordinates: (589, 97)
# Red dot coordinates: (591, 97)
# Red dot coordinates: (592, 98)
# Red dot coordinates: (593, 98)
# Red dot coordinates: (597, 102)
# Red dot coordinates: (597, 107)
# Red dot coordinates: (598, 108)
# Red dot coordinates: (598, 116)
# Red dot coordinates: (599, 117)
# Red dot coordinates: (599, 128)
# Red dot coordinates: (600, 129)
# Red dot coordinates: (600, 133)
# Red dot coordinates: (601, 134)
# Red dot coordinates: (601, 138)
# Red dot coordinates: (602, 139)
# Red dot coordinates: (602, 142)
# Red dot coordinates: (603, 143)
# Red dot coordinates: (603, 157)
# Red dot coordinates: (604, 158)
# Red dot coordinates: (604, 161)
# Red dot coordinates: (605, 162)
# Red dot coordinates: (605, 169)
# Red dot coordinates: (606, 170)
# Red dot coordinates: (606, 174)
# Red dot coordinates: (607, 175)
# Red dot coordinates: (607, 176)
# Red dot coordinates: (609, 176)
# Red dot coordinates: (610, 177)
# Red dot coordinates: (611, 177)
# Red dot coordinates: (612, 178)
# Red dot coordinates: (624, 178)
# Red dot coordinates: (625, 177)
# Red dot coordinates: (626, 177)
# Red dot coordinates: (627, 176)
# Red dot coordinates: (629, 176)
# Red dot coordinates: (631, 174)
# Red dot coordinates: (632, 174)
# Red dot coordinates: (633, 173)
# Red dot coordinates: (636, 173)
# Red dot coordinates: (637, 172)
# Red dot coordinates: (638, 172)
# Red dot coordinates: (639, 171)
# Red dot coordinates: (640, 171)
# Red dot coordinates: (641, 170)
# Red dot coordinates: (643, 170)
# Red dot coordinates: (644, 169)
# Red dot coordinates: (647, 169)
# Red dot coordinates: (648, 168)
# Red dot coordinates: (649, 168)
# Red dot coordinates: (651, 166)
# Red dot coordinates: (652, 166)
# Red dot coordinates: (655, 163)
# Red dot coordinates: (656, 163)
# Red dot coordinates: (657, 162)
# Red dot coordinates: (658, 162)
# Red dot coordinates: (659, 161)
# Red dot coordinates: (661, 161)
# Red dot coordinates: (662, 160)
# Red dot coordinates: (664, 160)
# Red dot coordinates: (665, 159)
# Red dot coordinates: (666, 159)
# Red dot coordinates: (667, 158)
# Red dot coordinates: (668, 158)
# Red dot coordinates: (669, 157)
# Red dot coordinates: (670, 157)
# Red dot coordinates: (671, 156)
# Red dot coordinates: (672, 156)
# Red dot coordinates: (673, 155)
# Red dot coordinates: (677, 155)
# Red dot coordinates: (678, 154)
# Red dot coordinates: (680, 154)
# Red dot coordinates: (681, 153)
# Red dot coordinates: (683, 153)
# Red dot coordinates: (684, 152)
# Red dot coordinates: (686, 152)
# Red dot coordinates: (687, 151)
# Red dot coordinates: (703, 151)
# Red dot coordinates: (704, 150)
# Red dot coordinates: (714, 150)
# Red dot coordinates: (715, 149)
# Red dot coordinates: (723, 149)
# Red dot coordinates: (724, 148)
# Red dot coordinates: (734, 148)
# Red dot coordinates: (735, 147)
# Red dot coordinates: (744, 147)
# Red dot coordinates: (745, 146)
# Red dot coordinates: (752, 146)
# Red dot coordinates: (753, 145)
# Red dot coordinates: (757, 145)
# Red dot coordinates: (758, 144)
# Red dot coordinates: (761, 144)
# Red dot coordinates: (762, 143)
# Red dot coordinates: (764, 143)
# Red dot coordinates: (765, 142)
# Red dot coordinates: (767, 142)
# Red dot coordinates: (768, 141)
# Red dot coordinates: (771, 141)
# Red dot coordinates: (772, 140)
# Red dot coordinates: (775, 140)
# Red dot coordinates: (776, 139)
# Red dot coordinates: (779, 139)
# Red dot coordinates: (780, 138)
# Red dot coordinates: (782, 138)
# Red dot coordinates: (783, 137)
# Red dot coordinates: (785, 137)
# Red dot coordinates: (786, 136)
# Red dot coordinates: (788, 136)
# Red dot coordinates: (789, 135)
# Red dot coordinates: (791, 135)
# Red dot coordinates: (792, 134)
# Red dot coordinates: (794, 134)
# Red dot coordinates: (795, 133)
# Red dot coordinates: (797, 133)
# Red dot coordinates: (798, 132)
# Red dot coordinates: (799, 133)
# Red dot coordinates: (801, 133)
# Red dot coordinates: (802, 134)
# Red dot coordinates: (803, 134)
# Red dot coordinates: (805, 136)
# Red dot coordinates: (806, 136)
# Red dot coordinates: (807, 137)
# Red dot coordinates: (808, 137)
# Red dot coordinates: (809, 138)
# Red dot coordinates: (814, 138)
# Red dot coordinates: (817, 141)
# Red dot coordinates: (818, 141)
# Red dot coordinates: (819, 142)
# Red dot coordinates: (820, 142)
# Red dot coordinates: (822, 144)
# Red dot coordinates: (822, 147)
# Red dot coordinates: (823, 148)
# Red dot coordinates: (823, 174)
# Red dot coordinates: (824, 175)
# Red dot coordinates: (824, 183)
# Red dot coordinates: (825, 184)
# Red dot coordinates: (825, 197)
# Red dot coordinates: (826, 198)
# Red dot coordinates: (826, 214)
# Red dot coordinates: (827, 215)
# Red dot coordinates: (827, 216)
# Red dot coordinates: (828, 217)
# Red dot coordinates: (829, 217)
# Red dot coordinates: (831, 219)
# Red dot coordinates: (831, 222)
# Red dot coordinates: (832, 223)
# Red dot coordinates: (832, 224)
# Red dot coordinates: (866, 224)
# Red dot coordinates: (867, 225)
# Red dot coordinates: (868, 225)
# Red dot coordinates: (869, 226)
# Red dot coordinates: (873, 226)
# Red dot coordinates: (874, 227)
# Red dot coordinates: (879, 227)
# Red dot coordinates: (880, 228)
# Red dot coordinates: (886, 228)
# Red dot coordinates: (887, 227)
# Red dot coordinates: (887, 226)
# Red dot coordinates: (888, 225)
# Red dot coordinates: (888, 224)
# Red dot coordinates: (890, 222)
# Red dot coordinates: (892, 222)
# Red dot coordinates: (893, 221)
# Red dot coordinates: (893, 220)
# Red dot coordinates: (894, 219)
# Red dot coordinates: (894, 215)
# Red dot coordinates: (893, 214)
# Red dot coordinates: (893, 213)
# Red dot coordinates: (892, 212)
# Red dot coordinates: (892, 202)
# Red dot coordinates: (891, 201)
# Red dot coordinates: (891, 200)
# Red dot coordinates: (893, 198)
# Red dot coordinates: (894, 198)
# Red dot coordinates: (895, 197)
# Red dot coordinates: (898, 197)
# Red dot coordinates: (899, 196)
# Red dot coordinates: (920, 196)
# Red dot coordinates: (921, 195)
# Red dot coordinates: (922, 195)
# Red dot coordinates: (923, 196)
# Red dot coordinates: (926, 196)
# Red dot coordinates: (930, 192)
# Red dot coordinates: (931, 192)
# Red dot coordinates: (937, 186)
# Red dot coordinates: (938, 186)
# Red dot coordinates: (940, 184)
# Red dot coordinates: (941, 184)
# Red dot coordinates: (941, 183)
# Red dot coordinates: (946, 178)
# Red dot coordinates: (946, 177)
# Red dot coordinates: (951, 172)
# Red dot coordinates: (951, 171)
# Red dot coordinates: (952, 170)
# Red dot coordinates: (952, 166)
# Red dot coordinates: (953, 165)
# Red dot coordinates: (953, 159)
# Red dot coordinates: (952, 158)
# Red dot coordinates: (952, 155)
# Red dot coordinates: (951, 154)
# Red dot coordinates: (951, 145)
# Red dot coordinates: (950, 144)
# Red dot coordinates: (950, 142)
# Red dot coordinates: (949, 141)
# Red dot coordinates: (949, 138)
# Red dot coordinates: (948, 137)
# Red dot coordinates: (948, 132)
# Red dot coordinates: (947, 131)
# Red dot coordinates: (947, 120)
# Red dot coordinates: (946, 119)
# Red dot coordinates: (946, 116)
# Red dot coordinates: (945, 115)
# Red dot coordinates: (945, 113)
# Red dot coordinates: (944, 112)
# Red dot coordinates: (944, 105)
# Red dot coordinates: (943, 104)
# Red dot coordinates: (943, 99)
# Red dot coordinates: (942, 98)
# Red dot coordinates: (942, 97)
# Red dot coordinates: (941, 96)
# Red dot coordinates: (941, 95)
# Red dot coordinates: (939, 93)
# Red dot coordinates: (941, 91)
# Red dot coordinates: (947, 91)
# Red dot coordinates: (948, 90)
# Red dot coordinates: (951, 90)
# Red dot coordinates: (952, 89)
# Red dot coordinates: (953, 89)
# Red dot coordinates: (957, 85)
# Red dot coordinates: (958, 85)
# Red dot coordinates: (962, 81)
# Red dot coordinates: (963, 81)
# Red dot coordinates: (966, 78)
# Red dot coordinates: (967, 78)
# Red dot coordinates: (969, 76)
# Red dot coordinates: (970, 76)
# Red dot coordinates: (971, 75)
# Red dot coordinates: (972, 75)
# Red dot coordinates: (974, 73)
# Red dot coordinates: (975, 73)
# Red dot coordinates: (976, 72)
# Red dot coordinates: (977, 72)
# Red dot coordinates: (978, 71)
# Red dot coordinates: (979, 71)
# Red dot coordinates: (980, 70)
# Red dot coordinates: (981, 70)
# Red dot coordinates: (982, 69)
# Red dot coordinates: (984, 69)
# Red dot coordinates: (985, 68)
# Red dot coordinates: (986, 68)
# Red dot coordinates: (987, 67)
# Red dot coordinates: (988, 67)
# Red dot coordinates: (989, 66)
# Red dot coordinates: (990, 66)
# Red dot coordinates: (991, 65)
# Red dot coordinates: (993, 65)
# Red dot coordinates: (994, 64)
# Red dot coordinates: (996, 64)
# Red dot coordinates: (997, 63)
# Red dot coordinates: (1000, 63)
# Red dot coordinates: (1001, 62)
# Red dot coordinates: (1002, 62)
# Red dot coordinates: (1004, 60)
# Red dot coordinates: (1005, 60)
# Red dot coordinates: (1006, 59)
# Red dot coordinates: (1007, 59)
# Red dot coordinates: (1009, 57)
# Red dot coordinates: (1010, 57)
# Red dot coordinates: (1011, 56)
# Red dot coordinates: (1012, 56)
# Red dot coordinates: (1015, 53)
# Red dot coordinates: (1016, 53)
# Red dot coordinates: (1018, 51)
# Red dot coordinates: (1019, 51)
# Red dot coordinates: (1021, 49)
# Red dot coordinates: (1022, 49)
# Red dot coordinates: (1023, 48)
# Red dot coordinates: (1024, 48)
# Red dot coordinates: (1025, 47)
# Red dot coordinates: (1028, 47)
# Red dot coordinates: (1029, 46)
# Red dot coordinates: (1030, 46)
# Red dot coordinates: (1031, 45)
# Red dot coordinates: (1032, 45)

# %%
# Reverse the y-coordinates
y_coords = max(y_coords) - y_coords

# MLP Model
model = Sequential()
model.add(Dense(32, input_dim=1, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Split the coordinates into training and test data
x_train, x_test, y_train, y_test = train_test_split(x_coords, y_coords, test_size=0.25, random_state=42)

# Convert the 1D arrays to 2D arrays for compatibility with the model
x_train = np.reshape(x_train, (-1, 1))
y_train = np.reshape(y_train, (-1, 1))
x_test = np.reshape(x_test, (-1, 1))
y_test = np.reshape(y_test, (-1, 1))

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0)

# %%
# Make predictions
predictions = model.predict(x_test)
# Out:
# 14/14 [==============================] - 0s 2ms/step

# %%
# Sort the test data points based on x_test
sorted_indices = np.argsort(x_test.flatten())
x_test_sorted = x_test[sorted_indices]
y_test_sorted = y_test[sorted_indices]
predictions_sorted = predictions[sorted_indices]

# Evaluate the model
mse = np.mean((predictions - y_test) ** 2)
print("Mean Squared Error (MSE):", mse)

# Plot the results
plt.figure(figsize=(8, 6))
plt.scatter(x_test_sorted, y_test_sorted, color='blue', label='Actual')
plt.plot(x_test_sorted, predictions_sorted, color='red', label='Predicted')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Approximation of Red Line with MLP')
plt.legend()
plt.show()
# Out:
# Mean Squared Error (MSE): 2458.833037601837
